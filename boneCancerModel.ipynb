# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16491, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 16491 (delta 27), reused 36 (delta 9), pack-reused 16408
# Receiving objects: 100% (16491/16491), 15.11 MiB | 8.80 MiB/s, done.
# Resolving deltas: 100% (11292/11292), done.

# %%
# !pip install -r yolov5/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.2/716.2 kB 13.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.5 MB/s eta 0:00:00
# ...

# %%
# !unzip train.zip

# %%
# %cd /content/yolov5
# !python train.py --img 416 --batch 16 --epochs 100 --data '../data.yaml' --cfg ./models/yolov5s.yaml --weights '' --name yolov5s_result --nosave --cache
# Out:
# /content/yolov5
# 2024-02-28 13:11:52.336116: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-28 13:11:52.336172: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-28 13:11:52.337552: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/yolov5s_result/weights/last.pt --conf 0.5 --img-size 640 --source /content/valid/images/IMG_2735_JPG_jpg.rf.7ba7a2fa445975cc5b342b1ad38bde59.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/yolov5s_result/weights/last.pt'], source=/content/valid/images/IMG_2735_JPG_jpg.rf.7ba7a2fa445975cc5b342b1ad38bde59.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-287-g574331f9 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/valid/images/IMG_2735_JPG_jpg.rf.7ba7a2fa445975cc5b342b1ad38bde59.jpg: 640x640 2 bone-cancers, 11.5ms
# Speed: 0.6ms pre-process, 11.5ms inference, 532.9ms NMS per image at shape (1, 3, 640, 640)
# ...
